# %% [markdown]
# <h2>Segmenting and Clustering Neighborhoods in Toronto<h2>
# <h3>Applied Data Science Capstone - week 3

# %% [markdown]
# <h5>Part 1: Getting + cleaning the data<h5>

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import json
import requests
from bs4 import BeautifulSoup as bsoup

# %%
req = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")

# %%
soup = bsoup(req.content,'lxml')
table = soup.find_all('table')[0]
df = pd.read_html(str(table))
neighborhood = pd.DataFrame(df[0])

# %%
neighborhood.head()
# Out:
#   Postal code           Borough                Neighborhood
# 0         M1A      Not assigned                         NaN
# 1         M2A      Not assigned                         NaN
# 2         M3A        North York                   Parkwoods
# 3         M4A        North York            Victoria Village
# 4         M5A  Downtown Toronto  Regent Park / Harbourfront

# %% [markdown]
# <h4>Note: we will not be using any Borough with value "Not assigned"<h4>

# %%
selct_neigh = neighborhood[(neighborhood['Borough'] != 'Not assigned') & (neighborhood['Borough'] != 'NaN')]

# %% [markdown]
# <h5>Clean up data<h5>

# %%
selct_neigh = selct_neigh.copy()
selct_neigh['Neighborhood'] = selct_neigh['Neighborhood'].str.replace(" /",",")
selct_neigh.head(11)
# Out:
#    Postal code           Borough                                 Neighborhood
# 2          M3A        North York                                    Parkwoods
# 3          M4A        North York                             Victoria Village
# 4          M5A  Downtown Toronto                    Regent Park, Harbourfront
# 5          M6A        North York             Lawrence Manor, Lawrence Heights
# 6          M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 8          M9A         Etobicoke                             Islington Avenue
# 9          M1B       Scarborough                               Malvern, Rouge
# 11         M3B        North York                                    Don Mills
# 12         M4B         East York              Parkview Hill, Woodbine Gardens
# 13         M5B  Downtown Toronto                     Garden District, Ryerson
# 14         M6B        North York                                    Glencairn

# %%
selct_neigh.shape
# Out:
# (103, 3)

# %% [markdown]
# <h3>Part 2: Get Neghborhoods' Geographical Coordinates<h3>

# %%
# !pip -q install geocoder
import geocoder

# %%
# make list of postal codes
post_codes = list(selct_neigh['Postal code'])

# initialize latitude, longitude lists
lats = []
lngs = []

# %%
# initialize coordinate variable to None
#lat_lng_coords = None

# loop though post_codes
#for pc in post_codes:
    # loop until you get the coordinates
#    while(lat_lng_coords is None):
#        g = geocoder.google(post_codes[0])
#        lat_lng_coords = g.latlng
    # split lat_lng_coords & append to respective list
#    [lat, lng] = lat_lng_coords
#    lats.append(lat)
#    lngs.append(lng)

# %% [markdown]
# <h5>As geocoder did not work for me, I used the workaround.<h5>

# %%
# !wget -q -O 'geographical_coordiantes.csv' https://cocl.us/Geospatial_data
print("got geographical_coordiantes.csv")
# Out:
# got geographical_coordiantes.csv

# %%
geo_coords_df = pd.read_csv('geographical_coordiantes.csv')
geo_coords_df.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
# extract geo-coords
for pc in post_codes:
    gc = geo_coords_df[['Latitude', 'Longitude']][geo_coords_df['Postal Code'] == pc].reset_index()
    # note: index at list(gc.loc[0])[0]
    lats.append(list(gc.loc[0])[1])
    lngs.append(list(gc.loc[0])[2])

# %%
print("I got", len(lats), "latitudes.")
print("I got", len(lngs), "longitudes.")
print("I should have", selct_neigh.shape[0], "of each.")
# Out:
# I got 103 latitudes.
# I got 103 longitudes.
# I should have 103 of each.

# %%
# adding Latitudes and Longitudes to our dataframe
selct_neigh['Latitude'] = lats
selct_neigh['Longitude'] = lngs

# %%
selct_neigh.head(11)
# Out:
#    Postal code           Borough                                 Neighborhood  \
# 2          M3A        North York                                    Parkwoods
# 3          M4A        North York                             Victoria Village
# 4          M5A  Downtown Toronto                    Regent Park, Harbourfront
# 5          M6A        North York             Lawrence Manor, Lawrence Heights
# 6          M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 8          M9A         Etobicoke                             Islington Avenue
# 9          M1B       Scarborough                               Malvern, Rouge
# 11         M3B        North York                                    Don Mills
# 12         M4B         East York              Parkview Hill, Woodbine Gardens
# 13         M5B  Downtown Toronto                     Garden District, Ryerson
# 14         M6B        North York                                    Glencairn
#
#      Latitude  Longitude
# 2   43.753259 -79.329656
# 3   43.725882 -79.315572
# 4   43.654260 -79.360636
# 5   43.718518 -79.464763
# 6   43.662301 -79.389494
# 8   43.667856 -79.532242
# 9   43.806686 -79.194353
# 11  43.745906 -79.352188
# 12  43.706397 -79.309937
# 13  43.657162 -79.378937
# 14  43.709577 -79.445073

# %% [markdown]
# <h3>Part 3: Explore and Cluster Neighborhoods<h3>

# %% [markdown]
# **You would think Neighborhoods with similar Postal Codes would be  next to each another
# ... but not necessarily**

# %%
# grouping neighborhoods by the middle digit in postal code
selct_neigh['Group'] = [int(t[1:2]) for t in list(selct_neigh['Postal code'])]
selct_neigh.head()
# Out:
#   Postal code           Borough                                 Neighborhood  \
# 2         M3A        North York                                    Parkwoods
# 3         M4A        North York                             Victoria Village
# 4         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 5         M6A        North York             Lawrence Manor, Lawrence Heights
# 6         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#     Latitude  Longitude  Group
# 2  43.753259 -79.329656      3
# 3  43.725882 -79.315572      4
# 4  43.654260 -79.360636      5
# 5  43.718518 -79.464763      6
# 6  43.662301 -79.389494      7

# %%
# install folium to plot map
# !pip -q install folium
import folium

# %% [markdown]
# <h5>Starting map centered around Downtown Toronto<h5>

# %%
neigh_map = folium.Map(location=[43.657162, -79.378937], zoom_start=10)

# %%
filt_neigh = selct_neigh[['Latitude', 'Longitude', 'Group']]
filt_neigh = filt_neigh.copy()

# %%
colrs=['pink', 
       'red', 
       'darkred', 
       'orange',
       'purple',
        'blue',
        'cadetblue', 
        'green', 
        'lightgreen'
        ]

# %%
# add neighborhoods to map
for lat, lng, label, pcode in zip(filt_neigh['Latitude'], filt_neigh['Longitude'], filt_neigh['Group'], selct_neigh['Postal code']):
    folium.vector_layers.CircleMarker(
        [lat, lng],
        radius=15,
        color=colrs[label-1], 
        popup=pcode,
        fill = True,
        fill_color=colrs[label-1],
        fill_opacity=0.6
    ).add_to(neigh_map)

# %% [markdown]
# <h3>Toronto's Neighborhoods<h3>
# <h5>Grouped by Middle Digit of Postal Code<h5>

# %%
neigh_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
